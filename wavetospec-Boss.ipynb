# %%
#Libraries#
###########
import os
import numpy as np
import matplotlib.pyplot as plt

#for loading and visualizing audio files
import librosa
import librosa.display

#to play audio
import IPython.display as ipd

# %%
def load_files(folder_name):
    audio_fpath = folder_name
    files = librosa.util.find_files(audio_fpath, ext=['wav'])
    files = np.asarray(files)
    counter = 101

    for y in files:
        print(y)
        data, sr = librosa.load(y, sr=44100)
        X = librosa.stft(data)
        Xdb = librosa.amplitude_to_db(abs(X))
        librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
        #plt.colorbar()
        plt.set_cmap('viridis')
        plt.ylim((19700, 20300))
        plt.xlim((1.3,2.7))
        plt.axis('off')
        plt.savefig("Images2/RL/RL" + str(counter) + ".png",dpi=300)
        counter+=1
        #plt.show()

# %%
#Load audio
load_files("f:\\Public\\Write\\WAV2\\RL")
# Out:
# f:\Public\Write\WAV2\RL\1614344425.wav
# f:\Public\Write\WAV2\RL\1614344431.wav
# f:\Public\Write\WAV2\RL\1614344436.wav
# f:\Public\Write\WAV2\RL\1614344442.wav
# f:\Public\Write\WAV2\RL\1614344447.wav
# f:\Public\Write\WAV2\RL\1614344562.wav
# f:\Public\Write\WAV2\RL\1614344572.wav
# f:\Public\Write\WAV2\RL\1614344577.wav
# f:\Public\Write\WAV2\RL\1614344583.wav
# f:\Public\Write\WAV2\RL\1614344588.wav
# f:\Public\Write\WAV2\RL\1614344594.wav
# f:\Public\Write\WAV2\RL\1614344600.wav
# f:\Public\Write\WAV2\RL\1614344606.wav
# f:\Public\Write\WAV2\RL\1614344611.wav
# f:\Public\Write\WAV2\RL\1614344617.wav
# f:\Public\Write\WAV2\RL\1614344624.wav
# f:\Public\Write\WAV2\RL\1614344630.wav
# f:\Public\Write\WAV2\RL\1614344637.wav
# f:\Public\Write\WAV2\RL\1614344643.wav
# f:\Public\Write\WAV2\RL\1614344665.wav
# f:\Public\Write\WAV2\RL\1614344673.wav
# f:\Public\Write\WAV2\RL\1614344678.wav
# f:\Public\Write\WAV2\RL\1614344685.wav
# f:\Public\Write\WAV2\RL\1614344691.wav
# f:\Public\Write\WAV2\RL\1614344698.wav
# f:\Public\Write\WAV2\RL\1614344703.wav
# f:\Public\Write\WAV2\RL\1614344709.wav
# f:\Public\Write\WAV2\RL\1614344715.wav
# f:\Public\Write\WAV2\RL\1614344721.wav
# f:\Public\Write\WAV2\RL\1614344727.wav
# f:\Public\Write\WAV2\RL\1614344733.wav
# f:\Public\Write\WAV2\RL\1614344738.wav
# f:\Public\Write\WAV2\RL\1614344744.wav
# f:\Public\Write\WAV2\RL\1614344750.wav
# f:\Public\Write\WAV2\RL\1614344756.wav
# f:\Public\Write\WAV2\RL\1614344762.wav
# f:\Public\Write\WAV2\RL\1614344768.wav
# f:\Public\Write\WAV2\RL\1614344775.wav
# f:\Public\Write\WAV2\RL\1614344783.wav
# f:\Public\Write\WAV2\RL\1614344833.wav
# f:\Public\Write\WAV2\RL\1614344840.wav
# f:\Public\Write\WAV2\RL\1614344847.wav
# f:\Public\Write\WAV2\RL\1614344853.wav
# f:\Public\Write\WAV2\RL\1614344859.wav
# f:\Public\Write\WAV2\RL\1614344866.wav
# f:\Public\Write\WAV2\RL\1614344872.wav
# f:\Public\Write\WAV2\RL\1614344877.wav
# f:\Public\Write\WAV2\RL\1614344883.wav
# f:\Public\Write\WAV2\RL\1614344889.wav
# f:\Public\Write\WAV2\RL\1614344894.wav
# f:\Public\Write\WAV2\RL\1614344900.wav
# f:\Public\Write\WAV2\RL\1614344906.wav
# f:\Public\Write\WAV2\RL\1614344912.wav
# f:\Public\Write\WAV2\RL\1614344917.wav
# f:\Public\Write\WAV2\RL\1614344923.wav
# f:\Public\Write\WAV2\RL\1614344929.wav
# f:\Public\Write\WAV2\RL\1614344934.wav
# f:\Public\Write\WAV2\RL\1614344940.wav
# f:\Public\Write\WAV2\RL\1614344946.wav
# f:\Public\Write\WAV2\RL\1614344951.wav
# f:\Public\Write\WAV2\RL\1614344957.wav
# f:\Public\Write\WAV2\RL\1614344963.wav
# f:\Public\Write\WAV2\RL\1614344969.wav
# f:\Public\Write\WAV2\RL\1614344975.wav
# f:\Public\Write\WAV2\RL\1614344980.wav
# f:\Public\Write\WAV2\RL\1614344986.wav
# f:\Public\Write\WAV2\RL\1614344994.wav
# f:\Public\Write\WAV2\RL\1614345003.wav
# f:\Public\Write\WAV2\RL\1614345009.wav
# f:\Public\Write\WAV2\RL\1614345014.wav
# f:\Public\Write\WAV2\RL\1614345020.wav
# f:\Public\Write\WAV2\RL\1614345026.wav
# f:\Public\Write\WAV2\RL\1614345032.wav
# f:\Public\Write\WAV2\RL\1614345045.wav
# f:\Public\Write\WAV2\RL\1614345051.wav
# f:\Public\Write\WAV2\RL\1614345056.wav
# f:\Public\Write\WAV2\RL\1614345062.wav
# f:\Public\Write\WAV2\RL\1614345068.wav
# f:\Public\Write\WAV2\RL\1614345073.wav
# f:\Public\Write\WAV2\RL\1614345079.wav
# f:\Public\Write\WAV2\RL\1614345231.wav
# f:\Public\Write\WAV2\RL\1614345237.wav
# f:\Public\Write\WAV2\RL\1614345242.wav
# f:\Public\Write\WAV2\RL\1614345247.wav
# f:\Public\Write\WAV2\RL\1614345253.wav
# f:\Public\Write\WAV2\RL\1614345258.wav
# f:\Public\Write\WAV2\RL\1614345264.wav
# f:\Public\Write\WAV2\RL\1614345269.wav
# f:\Public\Write\WAV2\RL\1614345275.wav
# f:\Public\Write\WAV2\RL\1614345280.wav
# f:\Public\Write\WAV2\RL\1614345285.wav
# f:\Public\Write\WAV2\RL\1614345291.wav
# f:\Public\Write\WAV2\RL\1614345296.wav
# f:\Public\Write\WAV2\RL\1614345301.wav
# f:\Public\Write\WAV2\RL\1614345306.wav
# f:\Public\Write\WAV2\RL\1614345312.wav
# f:\Public\Write\WAV2\RL\1614345318.wav
# f:\Public\Write\WAV2\RL\1614345323.wav
# f:\Public\Write\WAV2\RL\1614345329.wav
# f:\Public\Write\WAV2\RL\1614345334.wav
