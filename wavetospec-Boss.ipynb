# %%
#Libraries#
###########
import os
import numpy as np
import matplotlib.pyplot as plt

#for loading and visualizing audio files
import librosa
import librosa.display

#to play audio
import IPython.display as ipd

# %%
def load_files(folder_name):
    audio_fpath = folder_name
    files = librosa.util.find_files(audio_fpath, ext=['wav'])
    files = np.asarray(files)
    counter = 101

    for y in files:
        print(y)
        data, sr = librosa.load(y, sr=44100)
        X = librosa.stft(data)
        Xdb = librosa.amplitude_to_db(abs(X))
        librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
        #plt.colorbar()
        plt.set_cmap('viridis')
        plt.ylim((19700, 20300))
        plt.xlim((1.3,2.7))
        plt.axis('off')
        plt.savefig("Images2/LR/LR" + str(counter) + ".png",dpi=300)
        counter+=1
        plt.show()

# %%
#Load audio
load_files("f:\\Public\\Write\\WAV2\\LR")
# Out:
# f:\Public\Write\WAV2\LR\1614347514.wav
# f:\Public\Write\WAV2\LR\1614347519.wav
# f:\Public\Write\WAV2\LR\1614347525.wav
# f:\Public\Write\WAV2\LR\1614347531.wav
# f:\Public\Write\WAV2\LR\1614347537.wav
# f:\Public\Write\WAV2\LR\1614347543.wav
# f:\Public\Write\WAV2\LR\1614347548.wav
# f:\Public\Write\WAV2\LR\1614347615.wav
# f:\Public\Write\WAV2\LR\1614347620.wav
# f:\Public\Write\WAV2\LR\1614347625.wav
# f:\Public\Write\WAV2\LR\1614347631.wav
# f:\Public\Write\WAV2\LR\1614347636.wav
# f:\Public\Write\WAV2\LR\1614347641.wav
# f:\Public\Write\WAV2\LR\1614347648.wav
# f:\Public\Write\WAV2\LR\1614347653.wav
# f:\Public\Write\WAV2\LR\1614347659.wav
# f:\Public\Write\WAV2\LR\1614347664.wav
# f:\Public\Write\WAV2\LR\1614347670.wav
# f:\Public\Write\WAV2\LR\1614347675.wav
# f:\Public\Write\WAV2\LR\1614347681.wav
# f:\Public\Write\WAV2\LR\1614347686.wav
# f:\Public\Write\WAV2\LR\1614347693.wav
# f:\Public\Write\WAV2\LR\1614347698.wav
# f:\Public\Write\WAV2\LR\1614347703.wav
# f:\Public\Write\WAV2\LR\1614347709.wav
# f:\Public\Write\WAV2\LR\1614347715.wav
# f:\Public\Write\WAV2\LR\1614347721.wav
# f:\Public\Write\WAV2\LR\1614347727.wav
# f:\Public\Write\WAV2\LR\1614347732.wav
# f:\Public\Write\WAV2\LR\1614347738.wav
# f:\Public\Write\WAV2\LR\1614347743.wav
# f:\Public\Write\WAV2\LR\1614347750.wav
# f:\Public\Write\WAV2\LR\1614347755.wav
# f:\Public\Write\WAV2\LR\1614347761.wav
# f:\Public\Write\WAV2\LR\1614347766.wav
# f:\Public\Write\WAV2\LR\1614347773.wav
# f:\Public\Write\WAV2\LR\1614347779.wav
# f:\Public\Write\WAV2\LR\1614347784.wav
# f:\Public\Write\WAV2\LR\1614347798.wav
# f:\Public\Write\WAV2\LR\1614347803.wav
# f:\Public\Write\WAV2\LR\1614347810.wav
# f:\Public\Write\WAV2\LR\1614347816.wav
# f:\Public\Write\WAV2\LR\1614347821.wav
# f:\Public\Write\WAV2\LR\1614347827.wav
# f:\Public\Write\WAV2\LR\1614347833.wav
# f:\Public\Write\WAV2\LR\1614347838.wav
# f:\Public\Write\WAV2\LR\1614347844.wav
# f:\Public\Write\WAV2\LR\1614347850.wav
# f:\Public\Write\WAV2\LR\1614347855.wav
# f:\Public\Write\WAV2\LR\1614347861.wav
# f:\Public\Write\WAV2\LR\1614347867.wav
# f:\Public\Write\WAV2\LR\1614347873.wav
# f:\Public\Write\WAV2\LR\1614347878.wav
# f:\Public\Write\WAV2\LR\1614347885.wav
# f:\Public\Write\WAV2\LR\1614347890.wav
# f:\Public\Write\WAV2\LR\1614347896.wav
# f:\Public\Write\WAV2\LR\1614347902.wav
# f:\Public\Write\WAV2\LR\1614347908.wav
# f:\Public\Write\WAV2\LR\1614347913.wav
# f:\Public\Write\WAV2\LR\1614347919.wav
# f:\Public\Write\WAV2\LR\1614347924.wav
# f:\Public\Write\WAV2\LR\1614347930.wav
# f:\Public\Write\WAV2\LR\1614347936.wav
# f:\Public\Write\WAV2\LR\1614347941.wav
# f:\Public\Write\WAV2\LR\1614347948.wav
# f:\Public\Write\WAV2\LR\1614347954.wav
# f:\Public\Write\WAV2\LR\1614347960.wav
# f:\Public\Write\WAV2\LR\1614347966.wav
# f:\Public\Write\WAV2\LR\1614348026.wav
# f:\Public\Write\WAV2\LR\1614348032.wav
# f:\Public\Write\WAV2\LR\1614348038.wav
# f:\Public\Write\WAV2\LR\1614348044.wav
# f:\Public\Write\WAV2\LR\1614348050.wav
# f:\Public\Write\WAV2\LR\1614348056.wav
# f:\Public\Write\WAV2\LR\1614348062.wav
# f:\Public\Write\WAV2\LR\1614348068.wav
# f:\Public\Write\WAV2\LR\1614348073.wav
# f:\Public\Write\WAV2\LR\1614348078.wav
# f:\Public\Write\WAV2\LR\1614348084.wav
# f:\Public\Write\WAV2\LR\1614348089.wav
# f:\Public\Write\WAV2\LR\1614348095.wav
# f:\Public\Write\WAV2\LR\1614348100.wav
# f:\Public\Write\WAV2\LR\1614348105.wav
# f:\Public\Write\WAV2\LR\1614348111.wav
# f:\Public\Write\WAV2\LR\1614348116.wav
# f:\Public\Write\WAV2\LR\1614348122.wav
# f:\Public\Write\WAV2\LR\1614348129.wav
# f:\Public\Write\WAV2\LR\1614348134.wav
# f:\Public\Write\WAV2\LR\1614348140.wav
# f:\Public\Write\WAV2\LR\1614348146.wav
# f:\Public\Write\WAV2\LR\1614348151.wav
# f:\Public\Write\WAV2\LR\1614348158.wav
# f:\Public\Write\WAV2\LR\1614348163.wav
# f:\Public\Write\WAV2\LR\1614348169.wav
# f:\Public\Write\WAV2\LR\1614348174.wav
# f:\Public\Write\WAV2\LR\1614348180.wav
# f:\Public\Write\WAV2\LR\1614348185.wav
# f:\Public\Write\WAV2\LR\1614348191.wav
# f:\Public\Write\WAV2\LR\1614348196.wav
# f:\Public\Write\WAV2\LR\1614348201.wav
