# %%
#Libraries#
###########
import os
import numpy as np
import matplotlib.pyplot as plt

#for loading and visualizing audio files
import librosa
import librosa.display

#to play audio
import IPython.display as ipd

# %%
def load_files(folder_name):
    audio_fpath = folder_name
    files = librosa.util.find_files(audio_fpath, ext=['wav'])
    files = np.asarray(files)
    counter = 1

    for y in files:
        print(y)
        data, sr = librosa.load(y, sr=44100)
        X = librosa.stft(data)
        Xdb = librosa.amplitude_to_db(abs(X))
        librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
        #plt.colorbar()
        plt.set_cmap('viridis')
        plt.ylim((19700, 20300))
        plt.xlim((1.3,2.7))
        plt.axis('off')
        plt.savefig("Images/DU/DU" + str(counter) + ".png",dpi=300)
        counter+=1
        plt.show()

# %%
#Load audio
load_files("f:\\Public\\Write\\WAV\\DU")
# Out:
# f:\Public\Write\WAV\DU\1614105949.wav
# f:\Public\Write\WAV\DU\1614105955.wav
# f:\Public\Write\WAV\DU\1614105961.wav
# f:\Public\Write\WAV\DU\1614106742.wav
# f:\Public\Write\WAV\DU\1614106750.wav
# f:\Public\Write\WAV\DU\1614106756.wav
# f:\Public\Write\WAV\DU\1614106762.wav
# f:\Public\Write\WAV\DU\1614106768.wav
# f:\Public\Write\WAV\DU\1614106823.wav
# f:\Public\Write\WAV\DU\1614106829.wav
# f:\Public\Write\WAV\DU\1614106835.wav
# f:\Public\Write\WAV\DU\1614106841.wav
# f:\Public\Write\WAV\DU\1614106846.wav
# f:\Public\Write\WAV\DU\1614106852.wav
# f:\Public\Write\WAV\DU\1614106857.wav
# f:\Public\Write\WAV\DU\1614106863.wav
# f:\Public\Write\WAV\DU\1614106869.wav
# f:\Public\Write\WAV\DU\1614106874.wav
# f:\Public\Write\WAV\DU\1614106880.wav
# f:\Public\Write\WAV\DU\1614106887.wav
# f:\Public\Write\WAV\DU\1614106892.wav
# f:\Public\Write\WAV\DU\1614106898.wav
# f:\Public\Write\WAV\DU\1614106904.wav
# f:\Public\Write\WAV\DU\1614106909.wav
# f:\Public\Write\WAV\DU\1614106915.wav
# f:\Public\Write\WAV\DU\1614106920.wav
# f:\Public\Write\WAV\DU\1614106926.wav
# f:\Public\Write\WAV\DU\1614106932.wav
# f:\Public\Write\WAV\DU\1614106937.wav
# f:\Public\Write\WAV\DU\1614106943.wav
