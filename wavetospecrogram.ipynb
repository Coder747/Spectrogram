# %%
#Libraries#
###########
import os
import numpy as np
import matplotlib.pyplot as plt

#for loading and visualizing audio files
import librosa
import librosa.display

#to play audio
import IPython.display as ipd

# %%
def load_files(folder_name):
    audio_fpath = folder_name
    files = librosa.util.find_files(audio_fpath, ext=['wav'])
    files = np.asarray(files)
    counter = 101

    for y in files:
        print(y)
        data, sr = librosa.load(y, sr=44100)
        X = librosa.stft(data)
        Xdb = librosa.amplitude_to_db(abs(X))
        librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
        #plt.colorbar()
        plt.set_cmap('viridis')
        plt.ylim((19700, 20300))
        plt.xlim((1.3,2.7))
        plt.axis('off')
        plt.savefig("Images2/P/P" + str(counter) + ".png",dpi=300)
        counter+=1
        plt.show()

# %%
#Load audio
load_files("f:\\Public\\Write\\WAV2\\P")
# Out:
# f:\Public\Write\WAV2\P\1614378020.wav
# f:\Public\Write\WAV2\P\1614378025.wav
# f:\Public\Write\WAV2\P\1614378031.wav
# f:\Public\Write\WAV2\P\1614378036.wav
# f:\Public\Write\WAV2\P\1614378043.wav
# f:\Public\Write\WAV2\P\1614378106.wav
# f:\Public\Write\WAV2\P\1614378112.wav
# f:\Public\Write\WAV2\P\1614378118.wav
# f:\Public\Write\WAV2\P\1614378125.wav
# f:\Public\Write\WAV2\P\1614378131.wav
# f:\Public\Write\WAV2\P\1614378136.wav
# f:\Public\Write\WAV2\P\1614378142.wav
# f:\Public\Write\WAV2\P\1614378147.wav
# f:\Public\Write\WAV2\P\1614378154.wav
# f:\Public\Write\WAV2\P\1614378160.wav
# f:\Public\Write\WAV2\P\1614378165.wav
# f:\Public\Write\WAV2\P\1614378170.wav
# f:\Public\Write\WAV2\P\1614378176.wav
# f:\Public\Write\WAV2\P\1614378182.wav
# f:\Public\Write\WAV2\P\1614378187.wav
# f:\Public\Write\WAV2\P\1614378193.wav
# f:\Public\Write\WAV2\P\1614378199.wav
# f:\Public\Write\WAV2\P\1614378204.wav
# f:\Public\Write\WAV2\P\1614378210.wav
# f:\Public\Write\WAV2\P\1614378215.wav
# f:\Public\Write\WAV2\P\1614378221.wav
# f:\Public\Write\WAV2\P\1614378226.wav
# f:\Public\Write\WAV2\P\1614378232.wav
# f:\Public\Write\WAV2\P\1614378237.wav
# f:\Public\Write\WAV2\P\1614378243.wav
# f:\Public\Write\WAV2\P\1614378248.wav
# f:\Public\Write\WAV2\P\1614378253.wav
# f:\Public\Write\WAV2\P\1614378259.wav
# f:\Public\Write\WAV2\P\1614378265.wav
# f:\Public\Write\WAV2\P\1614378270.wav
# f:\Public\Write\WAV2\P\1614378277.wav
# f:\Public\Write\WAV2\P\1614378283.wav
# f:\Public\Write\WAV2\P\1614378288.wav
# f:\Public\Write\WAV2\P\1614378294.wav
# f:\Public\Write\WAV2\P\1614378300.wav
# f:\Public\Write\WAV2\P\1614378305.wav
# f:\Public\Write\WAV2\P\1614378311.wav
# f:\Public\Write\WAV2\P\1614378329.wav
# f:\Public\Write\WAV2\P\1614378335.wav
# f:\Public\Write\WAV2\P\1614378341.wav
# f:\Public\Write\WAV2\P\1614378346.wav
# f:\Public\Write\WAV2\P\1614378352.wav
# f:\Public\Write\WAV2\P\1614378357.wav
# f:\Public\Write\WAV2\P\1614378363.wav
# f:\Public\Write\WAV2\P\1614378369.wav
# f:\Public\Write\WAV2\P\1614378374.wav
# f:\Public\Write\WAV2\P\1614378385.wav
# f:\Public\Write\WAV2\P\1614378399.wav
# f:\Public\Write\WAV2\P\1614378405.wav
# f:\Public\Write\WAV2\P\1614378411.wav
# f:\Public\Write\WAV2\P\1614378416.wav
# f:\Public\Write\WAV2\P\1614378422.wav
# f:\Public\Write\WAV2\P\1614378427.wav
# f:\Public\Write\WAV2\P\1614378433.wav
# f:\Public\Write\WAV2\P\1614378438.wav
# f:\Public\Write\WAV2\P\1614378444.wav
# f:\Public\Write\WAV2\P\1614378450.wav
# f:\Public\Write\WAV2\P\1614378456.wav
# f:\Public\Write\WAV2\P\1614378462.wav
# f:\Public\Write\WAV2\P\1614378468.wav
# f:\Public\Write\WAV2\P\1614378473.wav
# f:\Public\Write\WAV2\P\1614378479.wav
# f:\Public\Write\WAV2\P\1614378486.wav
# f:\Public\Write\WAV2\P\1614378493.wav
# f:\Public\Write\WAV2\P\1614378500.wav
# f:\Public\Write\WAV2\P\1614378505.wav
# f:\Public\Write\WAV2\P\1614378511.wav
# f:\Public\Write\WAV2\P\1614378516.wav
# f:\Public\Write\WAV2\P\1614378522.wav
# f:\Public\Write\WAV2\P\1614378527.wav
# f:\Public\Write\WAV2\P\1614378533.wav
# f:\Public\Write\WAV2\P\1614378550.wav
# f:\Public\Write\WAV2\P\1614378555.wav
# f:\Public\Write\WAV2\P\1614378561.wav
# f:\Public\Write\WAV2\P\1614378567.wav
# f:\Public\Write\WAV2\P\1614378572.wav
# f:\Public\Write\WAV2\P\1614378578.wav
# f:\Public\Write\WAV2\P\1614378583.wav
# f:\Public\Write\WAV2\P\1614378589.wav
# f:\Public\Write\WAV2\P\1614378594.wav
# f:\Public\Write\WAV2\P\1614378600.wav
# f:\Public\Write\WAV2\P\1614378607.wav
# f:\Public\Write\WAV2\P\1614378612.wav
# f:\Public\Write\WAV2\P\1614378618.wav
# f:\Public\Write\WAV2\P\1614378624.wav
# f:\Public\Write\WAV2\P\1614378631.wav
# f:\Public\Write\WAV2\P\1614378636.wav
# f:\Public\Write\WAV2\P\1614378642.wav
# f:\Public\Write\WAV2\P\1614378648.wav
# f:\Public\Write\WAV2\P\1614378653.wav
# f:\Public\Write\WAV2\P\1614378668.wav
# f:\Public\Write\WAV2\P\1614378674.wav
# f:\Public\Write\WAV2\P\1614378679.wav
# f:\Public\Write\WAV2\P\1614378685.wav
# f:\Public\Write\WAV2\P\1614378690.wav
