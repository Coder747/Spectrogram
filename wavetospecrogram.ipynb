# %%
#Libraries#
###########
import os
import numpy as np
import matplotlib.pyplot as plt

#for loading and visualizing audio files
import librosa
import librosa.display

#to play audio
import IPython.display as ipd

# %%
def load_files(folder_name):
    audio_fpath = folder_name
    files = librosa.util.find_files(audio_fpath, ext=['wav'])
    files = np.asarray(files)
    counter = 1

    for y in files:
        print(y)
        data, sr = librosa.load(y, sr=44100)
        X = librosa.stft(data)
        Xdb = librosa.amplitude_to_db(abs(X))
        librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
        #plt.colorbar()
        plt.set_cmap('viridis')
        plt.ylim((19700, 20300))
        plt.xlim((1.3,2.7))
        plt.axis('off')
        #plt.savefig("Images_Mono/P/bot/P" + str(counter) + ".png",dpi=300)
        counter+=1
        plt.show()

# %%
#Load audio
load_files("C:\\Users\Admin-Group11\Desktop\\testing")
# Out:
# C:\Users\Admin-Group11\Desktop\testing\1616412304.wav
# C:\Users\Admin-Group11\Desktop\testing\1616412313.wav
# C:\Users\Admin-Group11\Desktop\testing\1616412329.wav
# C:\Users\Admin-Group11\Desktop\testing\1616412335.wav
# C:\Users\Admin-Group11\Desktop\testing\1616412347.wav
