# %%
#Libraries#
###########
import os
import numpy as np
import matplotlib.pyplot as plt

#for loading and visualizing audio files
import librosa
import librosa.display

#to play audio
import IPython.display as ipd

# %%
#Load audio
#audio_fpath = os.getcwd() + "\\Audio\\5alsana21.wav"
audio_fpath = "f:\\Public\\Write\\FinalSonar\\Close up\\Noise free Ibrahim\\Close_up_noise_free24.wav"
x, sr = librosa.load(audio_fpath, sr=44100)

# %%
#Librosa
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))

# %%
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
#plt.colorbar()
plt.set_cmap('viridis')
plt.ylim((19800, 20200))
plt.xlim((0.28,2.7))
plt.axis('off')
plt.savefig("Images/test5.png",dpi=300)
plt.show()
